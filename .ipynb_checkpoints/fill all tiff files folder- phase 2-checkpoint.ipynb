# %%
# %matplotlib notebook
import numpy as np
from numpy.fft import fft2, ifft2, fftshift
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import cm
import scipy
from scipy.ndimage import gaussian_filter1d as gf1d
from scipy.ndimage import gaussian_filter as gf
from scipy.ndimage import uniform_filter as uf

import sys
sys.path.append("../kai_colloids/PyDDM") #must point to the PyDDM folder
#import ddm_analysis_and_fitting as ddm

import tiff_file
import ddm_clean 

import io 
import sys
import csv
import os
import glob #glob is helpful for searching for filenames or directories
import pickle #for saving data
# Out:
# C:\Users\gleech\Documents\GitHub\kai codes\kai_colloids\tiff_file.py:1995: UserWarning: failed to import _tifffile.decodepackbits
#   warnings.warn("failed to import %s" % module_function)
# C:\Users\gleech\Documents\GitHub\kai codes\kai_colloids\tiff_file.py:1995: UserWarning: failed to import _tifffile.decodelzw
#   warnings.warn("failed to import %s" % module_function)
# C:\Users\gleech\Documents\GitHub\kai codes\kai_colloids\tiff_file.py:1995: UserWarning: failed to import _tifffile.unpackints
#   warnings.warn("failed to import %s" % module_function)

# %%
def last_3chars(x):
    return((x.split('\\')[-1])[-7:-4])

# %%
directory = "Z"
exp = "1-26-23 actin only + kai CL"

base_dir = directory+":\\Gregor L\\___Kai phase 2\\"+exp+"\\lightsheet\\all tiff file folders\\"

new_tif_dir = directory+":\\Gregor L\\___Kai phase 2\\"+exp+"\\lightsheet\\all tiff files\\"
print(new_tif_dir)
# Out:
# Z:\Gregor L\___Kai phase 2\1-26-23 actin only + kai CL\lightsheet\all tiff files\

# %%
folders = glob.glob(base_dir+"*_*")
print("found %i files" % len(folders))
for i,f in enumerate(folders): print (' %i \t %s' % (i, f.split('\\')[-1]))
# Out:
# found 54 files
#  0 	 las-561_time-0_pos-0_1
#  1 	 las-561_time-0_pos-1_1
#  2 	 las-561_time-0_pos-2_1
#  3 	 las-561_time-10_pos-0_1
#  4 	 las-561_time-10_pos-1_1
#  5 	 las-561_time-10_pos-2_1
#  6 	 las-561_time-11_pos-0_1
#  7 	 las-561_time-11_pos-1_1
#  8 	 las-561_time-11_pos-2_1
#  9 	 las-561_time-12_pos-0_1
#  10 	 las-561_time-12_pos-1_1
#  11 	 las-561_time-12_pos-2_1
#  12 	 las-561_time-13_pos-0_1
#  13 	 las-561_time-13_pos-1_1
#  14 	 las-561_time-13_pos-2_1
#  15 	 las-561_time-14_pos-0_1
#  16 	 las-561_time-14_pos-1_1
#  17 	 las-561_time-14_pos-2_1
#  18 	 las-561_time-15_pos-0_1
#  19 	 las-561_time-15_pos-1_1
#  20 	 las-561_time-15_pos-2_1
#  21 	 las-561_time-16_pos-0_1
#  22 	 las-561_time-16_pos-1_1
#  23 	 las-561_time-16_pos-2_1
#  24 	 las-561_time-17_pos-0_1
#  25 	 las-561_time-17_pos-1_1
#  26 	 las-561_time-17_pos-2_1
#  27 	 las-561_time-1_pos-0_1
#  28 	 las-561_time-1_pos-1_1
#  29 	 las-561_time-1_pos-2_1
#  30 	 las-561_time-2_pos-0_1
#  31 	 las-561_time-2_pos-1_1
#  32 	 las-561_time-2_pos-2_1
#  33 	 las-561_time-3_pos-0_1
#  34 	 las-561_time-3_pos-1_1
#  35 	 las-561_time-3_pos-2_1
#  36 	 las-561_time-4_pos-0_1
#  37 	 las-561_time-4_pos-1_1
#  38 	 las-561_time-4_pos-2_1
#  39 	 las-561_time-5_pos-0_1
#  40 	 las-561_time-5_pos-1_1
#  41 	 las-561_time-5_pos-2_1
#  42 	 las-561_time-6_pos-0_1
#  43 	 las-561_time-6_pos-1_1
#  44 	 las-561_time-6_pos-2_1
#  45 	 las-561_time-7_pos-0_1
#  46 	 las-561_time-7_pos-1_1
#  47 	 las-561_time-7_pos-2_1
#  48 	 las-561_time-8_pos-0_1
#  49 	 las-561_time-8_pos-1_1
#  50 	 las-561_time-8_pos-2_1
#  51 	 las-561_time-9_pos-0_1
#  52 	 las-561_time-9_pos-1_1
#  53 	 las-561_time-9_pos-2_1

# %%
for i in range(int(len(folders))):
    tiff_folder = folders[i]
    #print(tiff_folder)
    files = glob.glob(tiff_folder+"\*.ome.tif")
    print("found %i files" % len(files))
    for i,f in enumerate(files): 
        print (' %i \t %s' % (i, f.split('\\')[-1]))
        
        full_filename = files[0]
        specific_file = (full_filename.split('\\')[-1])[:-21]

        tiff_length = len(tiff_file.imread(files[0]))
        print(tiff_length)

        if tiff_length == 21:
            new_tiff = np.zeros((21, 500, 1500), dtype=np.uint16)
            for j in range(tiff_length):
                tiff_obj = tiff_file.imread(files[0],key=[j])
                new_tiff[j] = tiff_obj
            tiff_file.imsave(new_tif_dir + specific_file + '.tif', new_tiff)

        elif tiff_length == 8:
            frame_num = [0, 2, 4, 6]
            new_tiff_488 = np.zeros((5, 1440, 1920), dtype=np.uint16)
            new_tiff_568 = np.zeros((5, 1440, 1920), dtype=np.uint16)
            for k in [0, 1, 2, 3]:
                j = frame_num[k]
                #print("j =" + str(j))
                tiff_obj_488 = tiff_file.imread(files[0],key=[j])
                new_tiff_488[k] = tiff_obj_488
                tiff_obj_568 = tiff_file.imread(files[0],key=[j+1])
                new_tiff_568[k] = tiff_obj_568
            tiff_file.imsave(new_tif_dir + specific_file + '_488.tif', new_tiff_488)
            tiff_file.imsave(new_tif_dir + specific_file + '_568.tif', new_tiff_568)
# Out:
# found 1 files
#  0 	 las-561_time-0_pos-0_1_MMStack_Default.ome.tif
# C:\Users\gleech\Documents\GitHub\kai codes\kai_colloids\tiff_file.py:724: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   result = numpy.vstack((p.asarray() if p else nopage)
# 21
# found 1 files
#  0 	 las-561_time-0_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-0_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-10_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-10_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-10_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-11_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-11_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-11_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-12_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-12_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-12_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-13_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-13_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-13_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-14_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-14_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-14_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-15_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-15_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-15_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-16_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-16_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-16_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-17_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-17_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-17_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-1_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-1_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-1_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-2_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-2_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-2_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-3_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-3_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-3_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-4_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-4_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-4_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-5_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-5_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-5_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-6_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-6_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-6_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-7_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-7_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-7_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-8_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-8_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-8_pos-2_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-9_pos-0_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-9_pos-1_1_MMStack_Default.ome.tif
# 21
# found 1 files
#  0 	 las-561_time-9_pos-2_1_MMStack_Default.ome.tif
# 21

# %%
print(len(tiff_file.imread(files[0])))
# Out:
# 4
# C:\Users\gleech\Documents\GitHub\kai codes\kai_colloids\tiff_file.py:724: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   result = numpy.vstack((p.asarray() if p else nopage)
